# %%
import numpy as np              
import matplotlib.pyplot as plt 
# %matplotlib inline 
import pandas as pd             
import seaborn as sns           
import sklearn

# %%
url = 'https://raw.githubusercontent.com/PlotnikovArtem/MachineLearningPractice/main/runs.csv'
data = pd.read_csv(url, delimiter=',',  engine='python')

# %% [markdown]
# Предположим, что вы хотите продать квартиру и желаете узнать, по какой цене следует продавать, чтобы не продешевить. Загрузим данные о ценах на нижегородские квартиры (данные в 2017 г. собрал Александр Коротких, за что ему выражаю огромную благодарность):

# %%
data
# Out:
#        race_id  horse_no  horse_id  result  won  lengths_behind  horse_age  \
# 0            0         1      3917      10  0.0            8.00          3
# 1            0         2      2157       8  0.0            5.75          3
# 2            0         3       858       7  0.0            4.75          3
# 3            0         4      1853       9  0.0            6.25          3
# 4            0         5      2796       6  0.0            3.75          3
# ...        ...       ...       ...     ...  ...             ...        ...
# 79442     6348        10      1238       6  0.0            1.25          5
# 79443     6348        11       985       7  0.0            2.25          5
# 79444     6348        12      3147      10  0.0            3.00          5
# 79445     6348        13      1982       8  0.0            2.50          3
# 79446     6348        14      3491      11  0.0            4.25          3
#
# ...
